# %%
# ================ SETUP INICIAL ================ #

import os
import importlib
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns

# Añadimos el path del módulo local 'src/'
import sys
sys.path.append(os.path.abspath("../src"))

# Recargamos módulo en caso de cambios recientes
import procesar_zscore
importlib.reload(procesar_zscore)
from procesar_zscore import procesar_archivo, transformar_a_formato_largo, validar_estructura, detectar_outliers_zscore, calcular_ratios_zlogit, winsorize_percentiles, winsorize_iqr, calcular_is_distressed

# %%
# Años que forman el panel
years = [2019, 2020, 2021, 2022, 2023]

# %%
# ================ PROCESAMIENTO DE ARCHIVOS ================ #

header_row = 14  # Ajusta si es necesario

dfs = []

for year in years:
    file_path = f"../data/zscore_sample{year}.csv"

    # 1. Leer encabezado IQ (línea 14, índice 14)
    with open(file_path) as f:
        for _ in range(header_row):
            next(f)
        header_1 = [col.strip().replace('"', '') for col in next(f).strip().split(",")]

    # 2. Leer datos reales (header + data)
    df_raw = pd.read_csv(file_path, header=None, skiprows=header_row+1)
    df_raw.columns = header_1

    print(f"\n{year} --- {df_raw[['IQ_INDUSTRY_CLASSIFICATION']].head(3)}")
    print(f"{year}: NaN en archivo: {df_raw['IQ_INDUSTRY_CLASSIFICATION'].isna().sum()} de {df_raw.shape[0]} filas")

    # 3. Procesa el archivo con tu función personalizada
    df_year = procesar_archivo(file_path, year)
    print(f"{year}: DataFrame procesado con shape {df_year.shape}")

    dfs.append(df_year)
# Out:
# 2019 ---   IQ_INDUSTRY_CLASSIFICATION
# 0     Consumer Discretionary
# 1                Industrials
# 2                 Financials
# 2019: NaN en archivo: 0 de 19515 filas
# 2019: DataFrame procesado con shape (19515, 20)
#
# 2020 ---   IQ_INDUSTRY_CLASSIFICATION
# 0                 Financials
# 1     Consumer Discretionary
# 2                Industrials
# 2020: NaN en archivo: 0 de 18771 filas
# 2020: DataFrame procesado con shape (18771, 20)
#
# 2021 ---   IQ_INDUSTRY_CLASSIFICATION
# 0     Consumer Discretionary
# 1                Industrials
# 2                 Financials
# 2021: NaN en archivo: 0 de 18229 filas
# 2021: DataFrame procesado con shape (18229, 20)
#
# 2022 ---   IQ_INDUSTRY_CLASSIFICATION
# 0     Consumer Discretionary
# 1     Consumer Discretionary
# 2                Industrials
# 2022: NaN en archivo: 0 de 17458 filas
# 2022: DataFrame procesado con shape (17458, 20)
#
# 2023 ---   IQ_INDUSTRY_CLASSIFICATION
# 0     Consumer Discretionary
# 1                Industrials
# 2                 Financials
# 2023: NaN en archivo: 0 de 16682 filas
# 2023: DataFrame procesado con shape (16682, 20)

# %%
# Validar estructura de todos los años
print(f"\nDataFrames procesados: {len(dfs)}")
for i, df in enumerate(dfs):
    print(f"Año {years[i]} - filas: {df.shape[0]} columnas: {df.shape[1]}")

validar_estructura(dfs)
# Out:
# DataFrames procesados: 5
# Año 2019 - filas: 19515 columnas: 20
# Año 2020 - filas: 18771 columnas: 20
# Año 2021 - filas: 18229 columnas: 20
# Año 2022 - filas: 17458 columnas: 20
# Año 2023 - filas: 16682 columnas: 20
# ⚠️ Año 2020: columnas diferentes: ['IQ_AVG_BASIC_SHARES_OUT_2019', 'IQ_AVG_BASIC_SHARES_OUT_2020', 'IQ_EBIT_2019', 'IQ_EBIT_2020', 'IQ_INTEREST_EXP_2019', 'IQ_INTEREST_EXP_2020', 'IQ_RETAINED_EARNINGS_2019', 'IQ_RETAINED_EARNINGS_2020', 'IQ_TOTAL_ASSETS_2019', 'IQ_TOTAL_ASSETS_2020', 'IQ_TOTAL_CA_2019', 'IQ_TOTAL_CA_2020', 'IQ_TOTAL_CL_2019', 'IQ_TOTAL_CL_2020', 'IQ_TOTAL_DEBT_2019', 'IQ_TOTAL_DEBT_2020', 'IQ_TOTAL_LIAB_2019', 'IQ_TOTAL_LIAB_2020', 'IQ_TOTAL_REV_2019', 'IQ_TOTAL_REV_2020']
# ⚠️ Año 2021: columnas diferentes: ['IQ_AVG_BASIC_SHARES_OUT_2019', 'IQ_AVG_BASIC_SHARES_OUT_2021', 'IQ_EBIT_2019', 'IQ_EBIT_2021', 'IQ_INTEREST_EXP_2019', 'IQ_INTEREST_EXP_2021', 'IQ_RETAINED_EARNINGS_2019', 'IQ_RETAINED_EARNINGS_2021', 'IQ_TOTAL_ASSETS_2019', 'IQ_TOTAL_ASSETS_2021', 'IQ_TOTAL_CA_2019', 'IQ_TOTAL_CA_2021', 'IQ_TOTAL_CL_2019', 'IQ_TOTAL_CL_2021', 'IQ_TOTAL_DEBT_2019', 'IQ_TOTAL_DEBT_2021', 'IQ_TOTAL_LIAB_2019', 'IQ_TOTAL_LIAB_2021', 'IQ_TOTAL_REV_2019', 'IQ_TOTAL_REV_2021']
# ⚠️ Año 2022: columnas diferentes: ['IQ_AVG_BASIC_SHARES_OUT_2019', 'IQ_AVG_BASIC_SHARES_OUT_2022', 'IQ_EBIT_2019', 'IQ_EBIT_2022', 'IQ_INTEREST_EXP_2019', 'IQ_INTEREST_EXP_2022', 'IQ_RETAINED_EARNINGS_2019', 'IQ_RETAINED_EARNINGS_2022', 'IQ_TOTAL_ASSETS_2019', 'IQ_TOTAL_ASSETS_2022', 'IQ_TOTAL_CA_2019', 'IQ_TOTAL_CA_2022', 'IQ_TOTAL_CL_2019', 'IQ_TOTAL_CL_2022', 'IQ_TOTAL_DEBT_2019', 'IQ_TOTAL_DEBT_2022', 'IQ_TOTAL_LIAB_2019', 'IQ_TOTAL_LIAB_2022', 'IQ_TOTAL_REV_2019', 'IQ_TOTAL_REV_2022']
# ⚠️ Año 2023: columnas diferentes: ['IQ_AVG_BASIC_SHARES_OUT_2019', 'IQ_AVG_BASIC_SHARES_OUT_2023', 'IQ_EBIT_2019', 'IQ_EBIT_2023', 'IQ_INTEREST_EXP_2019', 'IQ_INTEREST_EXP_2023', 'IQ_RETAINED_EARNINGS_2019', 'IQ_RETAINED_EARNINGS_2023', 'IQ_TOTAL_ASSETS_2019', 'IQ_TOTAL_ASSETS_2023', 'IQ_TOTAL_CA_2019', 'IQ_TOTAL_CA_2023', 'IQ_TOTAL_CL_2019', 'IQ_TOTAL_CL_2023', 'IQ_TOTAL_DEBT_2019', 'IQ_TOTAL_DEBT_2023', 'IQ_TOTAL_LIAB_2019', 'IQ_TOTAL_LIAB_2023', 'IQ_TOTAL_REV_2019', 'IQ_TOTAL_REV_2023']

# %%
# Unir todos los años
df_panel = pd.concat(dfs, axis=0).reset_index(drop=True)
print(f"Panel final: {df_panel.shape}")
# Out:
# Panel final: (90655, 60)

# %%
# Chequeo de valores
for year in years:
    df_sub = df_panel[df_panel["year"] == year]
    total = df_sub.shape[0]
    notnull = df_sub["IQ_INDUSTRY_CLASSIFICATION"].notna().sum()
    print(f"{year}: {notnull} valores no vacíos de {total} filas")
# Out:
# 2019: 19515 valores no vacíos de 19515 filas
# 2020: 18771 valores no vacíos de 18771 filas
# 2021: 18229 valores no vacíos de 18229 filas
# 2022: 17458 valores no vacíos de 17458 filas
# 2023: 16682 valores no vacíos de 16682 filas

# %%
df_year = procesar_archivo(file_path, year)
dfs.append(df_year)

# %%
print(f"Año {year} procesado: {df_year.shape}")
dfs.append(df_year)
# Out:
# Año 2023 procesado: (16682, 20)

# %%
print(df_panel.head(5))
# Out:
#                                  SP_ENTITY_NAME  SP_ENTITY_ID  \
# 0       1-800-FLOWERS.COM, Inc. (NASDAQGS:FLWS)       4122591
# 1                             1847 Holdings LLC       7019095
# 2  1895 Bancorp of Wisconsin, Inc. (OTCQX:BCOW)      11123920
# 3             1911 Gold Corporation (TSXV:AUMB)      10803812
# 4              1933 Industries Inc. (CNSX:TGIF)       4812052
#
#                SP_GEOGRAPHY SP_COUNTRY_NAME  SP_COMPANY_TYPE  \
# 0  United States and Canada             USA   Public Company
# 1  United States and Canada             USA  Private Company
# 2  United States and Canada             USA   Public Company
# 3  United States and Canada          Canada   Public Company
# 4  United States and Canada          Canada   Public Company
#
#   IQ_INDUSTRY_CLASSIFICATION SP_COMPANY_STATUS  SP_YEAR_INCORPORATED  \
# 0     Consumer Discretionary         Operating                1992.0
# 1                Industrials         Operating                2013.0
# 2                 Financials         Operating                2019.0
# 3                  Materials         Operating                2018.0
# 4                Health Care         Operating                   NaN
#
#    IQ_TOTAL_ASSETS_2019  IQ_TOTAL_REV_2019  ...  IQ_TOTAL_ASSETS_2023  \
# 0         606440.000000       1.248623e+06  ...                   NaN
# 1          19294.792000       6.380025e+03  ...                   NaN
# 2         428009.000000       1.632000e+04  ...                   NaN
# 3          37301.229342       9.254149e+03  ...                   NaN
# 4          46908.072370       1.364398e+04  ...                   NaN
#
#    IQ_TOTAL_REV_2023  IQ_TOTAL_DEBT_2023  IQ_INTEREST_EXP_2023  \
# 0                NaN                 NaN                   NaN
# 1                NaN                 NaN                   NaN
# 2                NaN                 NaN                   NaN
# 3                NaN                 NaN                   NaN
# 4                NaN                 NaN                   NaN
#
#    IQ_TOTAL_CA_2023  IQ_TOTAL_CL_2023  IQ_RETAINED_EARNINGS_2023  \
# 0               NaN               NaN                        NaN
# 1               NaN               NaN                        NaN
# 2               NaN               NaN                        NaN
# 3               NaN               NaN                        NaN
# 4               NaN               NaN                        NaN
#
#    IQ_EBIT_2023  IQ_TOTAL_LIAB_2023  IQ_AVG_BASIC_SHARES_OUT_2023
# 0           NaN                 NaN                           NaN
# 1           NaN                 NaN                           NaN
# 2           NaN                 NaN                           NaN
# 3           NaN                 NaN                           NaN
# 4           NaN                 NaN                           NaN
#
# [5 rows x 60 columns]

# %%
# Transformamos a formato largo
df_largo = transformar_a_formato_largo(df_panel)
print(f"Panel largo generado: {df_largo.shape[0]} filas y {df_largo.shape[1]} columnas")
# Out:
# Panel largo generado: 90654 filas y 20 columnas

# %%
# Validación inicial del panel largo
print("Distribución de años:")
print(df_largo["year"].value_counts(), "\n")

print("Tipos de datos:")
print(df_largo.dtypes, "\n")

print("Porcentaje de nulos por columna:")
print(df_largo.isna().mean().sort_values(ascending=False).head(10), "\n")

print("Número de filas duplicadas:", df_largo.duplicated().sum())
# Out:
# Distribución de años:
# year
# 2019    19515
# 2020    18771
# 2021    18229
# 2022    17458
# 2023    16681
# Name: count, dtype: int64
#
# Tipos de datos:
# SP_ENTITY_NAME                 object
# SP_ENTITY_ID                    int64
# SP_GEOGRAPHY                   object
# SP_COUNTRY_NAME                object
# SP_COMPANY_TYPE                object
# IQ_INDUSTRY_CLASSIFICATION     object
# SP_COMPANY_STATUS              object
# SP_YEAR_INCORPORATED          float64
# SP_PRICE_CLOSE                float64
# year                            int64
# IQ_TOTAL_ASSETS               float64
# IQ_TOTAL_REV                  float64
# IQ_TOTAL_DEBT                 float64
# IQ_INTEREST_EXP               float64
# IQ_TOTAL_CA                   float64
# IQ_TOTAL_CL                   float64
# IQ_RETAINED_EARNINGS          float64
# IQ_EBIT                       float64
# IQ_TOTAL_LIAB                 float64
# IQ_AVG_BASIC_SHARES_OUT       float64
# dtype: object
#
# Porcentaje de nulos por columna:
# SP_PRICE_CLOSE             0.586736
# SP_YEAR_INCORPORATED       0.349869
# IQ_AVG_BASIC_SHARES_OUT    0.346085
# IQ_INTEREST_EXP            0.320184
# IQ_EBIT                    0.246685
# IQ_RETAINED_EARNINGS       0.040903
# IQ_TOTAL_CL                0.005185
# IQ_TOTAL_DEBT              0.004434
# IQ_TOTAL_CA                0.003905
# IQ_TOTAL_LIAB              0.003662
# dtype: float64
#
# Número de filas duplicadas: 0

# %%
# Media y mediana SOLO para empresas listadas en bolsa
listed = df_largo[~df_largo['SP_PRICE_CLOSE'].isna()]
print("Empresas listadas:", listed.shape[0])
print("Media precio de cierre:", listed['SP_PRICE_CLOSE'].mean())
print("Mediana precio de cierre:", listed['SP_PRICE_CLOSE'].median())

# Media de interest_exp SOLO para empresas con deuda
with_debt = df_largo[~df_largo['IQ_TOTAL_DEBT'].isna() & (df_largo['IQ_TOTAL_DEBT'] > 0)]
print("Empresas con deuda:", with_debt.shape[0])
print("Media gasto intereses:", with_debt['IQ_INTEREST_EXP'].mean())
# Out:
# Empresas listadas: 37464
# Media precio de cierre: 812514.3630717306
# Mediana precio de cierre: 9.73558729717572
# Empresas con deuda: 82795
# Media gasto intereses: -50258.21533296133

# %%
# Detección de outliers
from scipy.stats import zscore

def detectar_outliers_zscore(df, columna, threshold=3):
    df = df.copy()
    z = zscore(df[columna].astype(float), nan_policy='omit')  # <- esto arregla el error
    df["z"] = z
    return df[df["z"].abs() > threshold]

# %%
# Paso 1: detectar los outliers y guardar el resultado
outliers_activos = detectar_outliers_zscore(df_largo, "IQ_TOTAL_ASSETS")

# Paso 2: visualizar algunas columnas
print(outliers_activos[["SP_ENTITY_NAME", "IQ_TOTAL_ASSETS", "year"]].head())
# Out:
#                                      SP_ENTITY_NAME  IQ_TOTAL_ASSETS  year
# 147                 ABN AMRO Bank N.V. (ENXTAM:ABN)     4.208888e+08  2019
# 353                         Aegon Ltd. (ENXTAM:AGN)     4.943811e+08  2019
# 725                           Allianz SE (XTRA:ALV)     1.134760e+09  2019
# 898   American International Group, Inc. (NYSE:AIG)     5.250640e+08  2019
# 1096                     Apple Inc. (NASDAQGS:AAPL)     3.385160e+08  2019

# %%
# Ver columnas IQ_ con tipo object
cols_object_iq = [
    col for col in df_panel.columns
    if col.startswith("IQ_") and df_panel[col].dtype == "object" and col != "IQ_INDUSTRY_CLASSIFICATION"
]

# %%
# Aplicamos limpieza solo si las hay
if cols_object_iq:
    print("Limpieza aplicada a columnas:", cols_object_iq)
    for col in cols_object_iq:
        df_panel[col] = limpiar_columna_numerica(df_panel[col])
else:
    print("No se detectaron columnas IQ_ tipo object numéricas. No se aplica limpieza.")
# Out:
# No se detectaron columnas IQ_ tipo object numéricas. No se aplica limpieza.

# %%
# Copiamos para no alterar el original
df_zlogit = df_largo.copy()

# Evitamos divisiones por cero
eps = 1e-6

# %%
# ================ CÁLCULO DE RATIOS ================ #
df_zlogit = calcular_ratios_zlogit(df_largo)

# %%
# Resumen estadístico de las nuevas variables
print(df_zlogit[["X1", "X2", "X3", "X4", "X5"]].describe())

# Ver porcentaje de nulos
print("\nPorcentaje de nulos por variable:")
print(df_zlogit[["X1", "X2", "X3", "X4", "X5"]].isna().mean().round(4) * 100)
# Out:
#                  X1            X2            X3            X4            X5
# count  90144.000000  86943.000000  68037.000000  3.686200e+04  90345.000000
# mean      -0.000423     -0.430426      0.042215  1.047316e+04      0.729970
# std        0.893064     12.274877      6.487736  2.324298e+05      5.982381
# min      -96.662187  -2207.054068   -129.185961  3.989014e-07      0.000009
# 25%       -0.171584     -0.043733     -0.009576  3.594232e+02      0.063316
# 50%        0.077053      0.050171      0.042906  1.361114e+03      0.452514
# 75%        0.284213      0.189191      0.102047  4.015654e+03      0.955831
# max        0.999988     28.941747   1661.455903  2.451335e+07   1663.220259
#
# Porcentaje de nulos por variable:
# X1     0.56
# X2     4.09
# X3    24.95
# X4    59.34
# X5     0.34
# dtype: float64

# %%
# Cargamos el dataframe limpio ya con X1 a X5
df = df_zlogit.copy()

# Lista de variables a truncar
ratios = ["X1", "X2", "X3", "X4", "X5"]

# Creamos gráficos boxplot y distribución antes de winsorizar
fig, axes = plt.subplots(len(ratios), 2, figsize=(12, 20))

for i, var in enumerate(ratios):
    sns.boxplot(x=df[var], ax=axes[i, 0])
    axes[i, 0].set_title(f"Boxplot antes de truncamiento: {var}")
    
    sns.histplot(df[var], kde=True, bins=50, ax=axes[i, 1])
    axes[i, 1].set_title(f"Distribución antes de truncamiento: {var}")

plt.tight_layout()
plt.show()

# %%
ratios_iqr = ["X1", "X2", "X3", "X5"]
ratio_pct = "X4"

# Aplicamos winsorizing por IQR
for col in ratios_iqr:
    df = winsorize_iqr(df, col)

df = winsorize_percentiles(df, ratio_pct)
# Out:
# X1: Winsorizado entre -1.311 y 1.424
# X2: Winsorizado entre -0.626 y 0.771
# X3: Winsorizado entre -0.289 y 0.381
# X5: Winsorizado entre -2.168 y 3.187
# X4: Winsorizado entre p1 = 7.065 y p99 = 82395.640

# %%
# Lista de variables ya winsorizadas
ratios = ["X1", "X2", "X3", "X4", "X5"]

# Creamos nuevos gráficos para comparar después del winsorizing
fig, axes = plt.subplots(len(ratios), 2, figsize=(12, 20))

for i, var in enumerate(ratios):
    sns.boxplot(x=df[var], ax=axes[i, 0])
    axes[i, 0].set_title(f"Boxplot después de truncamiento: {var}")

    sns.histplot(df[var], kde=True, bins=50, ax=axes[i, 1])
    axes[i, 1].set_title(f"Distribución después de truncamiento: {var}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Construcción de la variable dependiente: `is_distressed`
#
# En esta sección construimos una variable binaria `is_distressed` como **proxy de quiebra financiera**.
# Dado que no contamos con una etiqueta explícita de “default” o “bankruptcy”, utilizamos señales financieras severas y objetivas como sustituto, siguiendo la lógica de estudios como Altman (2016) y Barboza (2017).
#
# ---
#
# ### ⚙️ Criterios aplicados (cada uno suma 1 punto):
#
# | Indicador | Fórmula | Umbral |
# |----------|---------|--------|
# | Patrimonio neto negativo | `Total Liabilities > Total Assets` | Verdadero |
# | EBIT / Activos muy bajo | `EBIT / Total Assets < -0.5` | Verdadero |
# | Retained Earnings / Activos muy bajo | `RE / Total Assets < -1.0` | Verdadero |
# | Working Capital / Activos negativo | `(CA - CL) / Total Assets < -0.2` | Verdadero |
# | Apalancamiento extremo | `Total Debt / Total Assets > 1.0` | Verdadero |
# | Intereses > EBIT | `Interest Expense > EBIT` (si EBIT < 0) | Verdadero |
#
# ---
#
# ### Regla de clasificación:
#
# - Si la empresa **cumple 2 o más condiciones** → `is_distressed = 1`
# - En caso contrario → `is_distressed = 0`
#
# ---
#
# ### 🎯 Objetivo:
#
# Esto nos permite construir un modelo de riesgo:
# - Basado en **criterios contables claros**
# - **Replicable**, defendible y útil para consultoría o estudios de crédito
# - Que clasifique entre 5–15% de empresas como en distress, lo cual es razonable a nivel empírico
#
# ---

# %%
# Aplicamos la función definida previamente para generar la variable binaria `is_distressed`
# Esta variable identifica empresas con señales financieras graves (proxy de quiebra)
df["is_distressed"] = calcular_is_distressed(df)

# %%
# Validamos la proporción de empresas clasificadas como "en distress" (valor 1)
# Idealmente buscamos un rango razonable de 5–15% del total
df["is_distressed"].value_counts(normalize=True)
# Out:
# is_distressed
# 0    0.910164
# 1    0.089836
# Name: proportion, dtype: float64

# %%
# Mostramos una muestra aleatoria de 10 empresas clasificadas como "distressed"
# Nos permite revisar si efectivamente presentan patrones negativos coherentes
df[df["is_distressed"] == 1].sample(10)
# Out:
#                                   SP_ENTITY_NAME  SP_ENTITY_ID  \
# 7442             Fresh Tracks Therapeutics, Inc.       5202690
# 17705                           Transphorm, Inc.       5197096
# 64588    Immunocore Holdings plc (NASDAQGS:IMCR)       5221051
# 84260              NeoVolta Inc. (NASDAQCM:NEOV)      10945663
# 64428    Hyloris Pharmaceuticals SA (ENXTBR:HYL)      19395272
# 78892    DigitalOcean Holdings, Inc. (NYSE:DOCN)      12907735
# 65982       Libra (Longhurst Group) Treasury plc       7254496
# 67463                                Nogin, Inc.       7643241
# 35809           T2 Biosystems, Inc. (OTCPK:TTOO)       4811292
# 63526  Ginkgo Bioworks Holdings, Inc. (NYSE:DNA)       5219401
#
#                    SP_GEOGRAPHY SP_COUNTRY_NAME  SP_COMPANY_TYPE  \
# 7442   United States and Canada             USA  Private Company
# 17705  United States and Canada             USA  Private Company
# 64588                    Europe  United Kingdom   Public Company
# 84260  United States and Canada             USA   Public Company
# 64428                    Europe         Belgium   Public Company
# 78892  United States and Canada             USA   Public Company
# 65982                    Europe  United Kingdom  Private Company
# 67463  United States and Canada             USA  Private Company
# 35809  United States and Canada             USA   Public Company
# 63526  United States and Canada             USA   Public Company
#
#       IQ_INDUSTRY_CLASSIFICATION     SP_COMPANY_STATUS  SP_YEAR_INCORPORATED  \
# 7442                 Health Care          Reorganizing                1987.0
# 17705     Information Technology  Operating Subsidiary                   NaN
# 64588                Health Care             Operating                2021.0
# 84260                Industrials             Operating                2018.0
# 64428                Health Care             Operating                2012.0
# 78892     Information Technology             Operating                2012.0
# 65982                 Financials  Operating Subsidiary                2012.0
# 67463     Information Technology           Liquidating                2021.0
# 35809                Health Care             Operating                2006.0
# 63526                  Materials             Operating                   NaN
#
#        SP_PRICE_CLOSE  year  ...       IQ_EBIT  IQ_TOTAL_LIAB  \
# 7442        67.500067  2019  ... -2.402700e+04   1.057000e+04
# 17705             NaN  2019  ... -1.191900e+04   4.685700e+04
# 64588       35.450000  2022  ... -5.170100e+04   1.878590e+05
# 84260        4.550000  2023  ... -2.635699e+03   3.949100e+01
# 64428        7.456755  2022  ... -1.212379e+04   7.287592e+03
# 78892       29.550000  2023  ...  6.669100e+04   1.774665e+06
# 65982             NaN  2022  ...  2.215185e+04   4.360688e+05
# 67463             NaN  2022  ... -4.008800e+04   1.479570e+05
# 35809     6200.000000  2020  ... -4.019700e+04   7.035200e+04
# 63526       10.790000  2022  ... -2.182314e+06   8.030440e+05
#
#        IQ_AVG_BASIC_SHARES_OUT        X1        X2        X3  \
# 7442                   67178.0  0.411817 -0.626043 -0.288632
# 17705               28153605.0 -1.311075 -0.626043 -0.288632
# 64588               45714923.0  0.708369 -0.626043 -0.098149
# 84260               32025620.0  0.993930 -0.626043 -0.288632
# 64428               27198925.0  0.725020 -0.626043 -0.186804
# 78892               90141000.0  0.212427 -0.235623  0.045649
# 65982                      NaN -0.006726  0.007569  0.052991
# 67463                2452082.0 -0.246807 -0.626043 -0.288632
# 35809                  24266.0  0.553681 -0.626043 -0.288632
# 63526               41976537.0  0.502936 -0.626043 -0.288632
#
#        MARKET_VALUE_EQUITY            X4        X5  is_distressed
# 7442          4.534520e+06    428.999007  0.436343              1
# 17705                  NaN           NaN  1.162931              1
# 64588         1.620594e+09   8626.650947  0.331005              1
# 84260         1.457166e+08  82395.640462  0.531184              1
# 64428         2.028157e+08  27830.280340  0.038747              1
# 78892         2.663667e+09   1500.940487  0.474264              1
# 65982                  NaN           NaN  0.052991              1
# 67463                  NaN           NaN  1.260740              1
# 35809         1.504492e+08   2138.520582  0.229267              1
# 63526         4.529268e+08    564.012475  0.188124              1
#
# [10 rows x 27 columns]

# %%
# Exportamos el dataset con la variable de salida ya construida
df.to_csv("../outputs/zscore_base_modelo_raw.csv", index=False)

# %%
# Eliminamos observaciones con NaN en X1–X5 o en is_distressed
vars_modelo = ["X1", "X2", "X3", "X4", "X5", "is_distressed"]
df_modelo = df.dropna(subset=vars_modelo).reset_index(drop=True)

print(f"Observaciones finales para modelado: {df_modelo.shape[0]}")
# Out:
# Observaciones finales para modelado: 31361

# %%
# Ordenamos las variables
cols_ordenadas = [
    "year", "SP_ENTITY_NAME", "SP_ENTITY_ID", "SP_COUNTRY_NAME", "SP_GEOGRAPHY", 
    "SP_COMPANY_TYPE", "SP_COMPANY_STATUS", "SP_YEAR_INCORPORATED", "SP_PRICE_CLOSE",
    "IQ_INDUSTRY_CLASSIFICATION",
    "IQ_TOTAL_ASSETS", "IQ_TOTAL_REV", "IQ_TOTAL_DEBT", "IQ_INTEREST_EXP",
    "IQ_TOTAL_CA", "IQ_TOTAL_CL", "IQ_RETAINED_EARNINGS", "IQ_EBIT", 
    "IQ_TOTAL_LIAB", "MARKET_VALUE_EQUITY", "IQ_AVG_BASIC_SHARES_OUT",
    "X1", "X2", "X3", "X4", "X5",
    "is_distressed"
]

df_modelo = df_modelo[cols_ordenadas]

# %%
# Exportamos el dataset con las variables ordenadas
# Este archivo servirá como base para entrenar modelos logísticos o de clasificación
df_modelo.to_csv("../outputs/zscore_base_modelo.csv", index=False)
